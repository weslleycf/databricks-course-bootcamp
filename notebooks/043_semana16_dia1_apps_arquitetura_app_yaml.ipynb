# %% [markdown]
# # 📓 Semana 16 · Dia 1 — Databricks Apps: arquitetura e app.yaml
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition (até 3 apps, auto-stop 24h) |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | GenAI Assoc (deploy), portfólio |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | Primeiro app publicado |
#
# ---

# %% [markdown]
# ## 📖 Teoria — O que são Databricks Apps
#
# **Databricks Apps** publica aplicações web (Streamlit, Flask, FastAPI, Next.js...) rodando na infraestrutura gerenciada — SEM Kubernetes, com **autenticação e governança nativas** (Unity Catalog).
#
# Na Free Edition: **até 3 apps**; apps param sozinhos após 24h (restart manual).

# %% [markdown]
# ## 📖 Teoria — Estrutura de um app
#
# ```
# app/
#  ├── app.yaml        # declaração do app (comando, ambiente)
#  ├── requirements.txt
#  └── app.py          # código (Streamlit/FastAPI)
# ```
#
# `app.yaml` mínimo:
# ```yaml
# env:
#   - name: APP_ENV
#     value: production
# command:
#   - streamlit
#   - run
#   - app.py
# ```

# %% [markdown]
# ### 💻 Na prática — Primeiro app Streamlit
#
# Crie o app de BI de vendas.

# %%
# app.py (Streamlit) — dashboard de vendas
import streamlit as st
import pyspark.sql.functions as F
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()
st.set_page_config(page_title="Vendas", layout="wide")
st.title("📊 Painel de Vendas")

df = spark.table("workspace.ouro.vendas_por_dia").toPandas()
st.line_chart(df.set_index("data_venda")["receita_total"])
st.dataframe(df.tail(30))
print("Código do app Streamlit (app.py).")

# %%
# app.yaml
yaml_app = """
env:
  - name: APP_ENV
    value: production
command:
  - streamlit
  - run
  - app.py
"""
print(yaml_app)
print("Coloque app.py + app.yaml + requirements.txt na pasta do app.")

# %% [markdown]
# ### 💻 Na prática — Publicando
#
# 1. **Apps → Create App** → nomeie e selecione a pasta.
# 2. Escolha o runtime (Python).
# 3. **Start**. O Databricks builda e publica.
# 4. Acesse o URL gerado (auth nativa com sua conta).
# 5. Na Free, o app para após 24h — reinicie quando precisar.

# %% [markdown]
# > 🎯 **Dica de prova**: Apps: `app.yaml` declara o comando; a plataforma gerencia build/deploy/auth. Pergunta: 'como publicar uma UI sem Kubernetes?' → Databricks Apps.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** O que o app.yaml declara?
#
# **2.** Por que Apps têm auth nativa?
#
# **3.** Publique o app e compartilhe o link (2 pessoas).
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** app.yaml
#
# O comando de execução e variáveis de ambiente — o Databricks gerencia o resto (build, escala, auth).
#
# **2.** Auth nativa
#
# Quem acessa o URL passa pelo login do workspace — sem implementar autenticação você mesmo.
#
# **3.** Compartilhar
#
# Qualquer usuário do workspace (ou público, se permitido) acessa com a permissão configurada.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
