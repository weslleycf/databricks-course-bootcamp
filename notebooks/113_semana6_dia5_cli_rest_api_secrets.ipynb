# %% [markdown]
# # 📓 Semana 6 · Dia 5 — Databricks CLI, REST API e secrets
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition (CLI/API) + 🔑 secrets avançados |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | DEP (plataforma) |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | Scripts CLI + secrets criados |
#
# ---

# %% [markdown]
# ## 📖 Teoria — Databricks CLI
#
# O CLI (`databricks`) permite tudo o que a UI faz, via terminal: jobs, clusters, pipelines, bundles, tokens, secrets. É a base de automação e CI/CD.
#
# **REST API 2.0**: os mesmos recursos via HTTP (jobs, catalogs, warehouses...). CLI é um cliente da API.

# %% [markdown]
# ### 💻 Na prática — Comandos essenciais
#
# Rode localmente (ou em %sh no notebook, se o domínio estiver liberado).

# %%
# Terminal local
# !databricks auth login
# !databricks jobs list
# !databricks pipelines list
# !databricks catalogs list
print("CLI conectado: jobs, pipelines, catálogos listados.")

# %%
# REST API (exemplo com curl)
# !curl -H "Authorization: Bearer $DATABRICKS_TOKEN" \
  "$DATABRICKS_HOST/api/2.1/jobs/list"
print("A API de jobs retorna JSON — usada por SDKs e scripts.")

# %% [markdown]
# ## 📖 Teoria — Secrets — nunca credenciais em código
#
# Credenciais (senhas, tokens, chaves de API) **nunca** devem ficar em notebooks ou código. Use **Secret Scopes**: cofre gerenciado (Databricks-backed) ou integrado (Vault/Key Vault em produção).
#
# Acesso no notebook: `dbutils.secrets.get(scope='meu_scope', key='senha')`.

# %% [markdown]
# ### 💻 Na prática — Criando e usando secrets
#
# No terminal (local) com o CLI conectado ao workspace.

# %%
# Terminal local
# !databricks secrets create-scope curso
# !databricks secrets put-secret curso senha_api --string-value "abc123"
print("Scope curso criado com a secret senha_api.")

# %%
# Uso no notebook — NUNCA imprima o valor em produção
senha = dbutils.secrets.get(scope="curso", key="senha_api")
print("Secret lida com sucesso (tamanho:", len(senha), "caracteres)")

# %% [markdown]
# > 🎯 **Dica de prova**: A DEP cobra: secrets scopes (Databricks-backed vs Key Vault), dbutils.secrets.get, e a regra de nunca expor credenciais. Na Free, scopes avançados (Key Vault) exigem conta paga.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Crie um scope e uma secret; leia no notebook sem imprimir o valor.
#
# **2.** Qual a diferença entre secrets Databricks-backed e Key Vault?
#
# **3.** Por que nunca colocar credenciais em variável de ambiente do notebook?
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** Prática
#
# `databricks secrets create-scope curso; put-secret ...` + `dbutils.secrets.get(...)` no notebook.
#
# **2.** Tipos
#
# Databricks-backed: armazenado no cofre gerenciado pelo Databricks (bom para começar). Key Vault: integração com o cofre da nuvem (produção, rotação e auditoria centralizadas).
#
# **3.** Credenciais no notebook
#
# Ficam versionadas no Git (vazamento), sem rotação e sem auditoria. Secrets scopes centralizam e protegem.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
