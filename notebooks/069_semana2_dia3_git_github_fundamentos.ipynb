# %% [markdown]
# # 📓 Semana 2 · Dia 3 — Git e GitHub do zero
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition (Git local + GitHub) |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | DEP (IaC/CI/CD), carreira |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | Repositório do curso criado no GitHub |
#
# ---

# %% [markdown]
# ## 📖 Teoria — Por que Git antes de DABs?
#
# A Semana 6 vai versionar pipelines com **Databricks Asset Bundles (DABs)** — e DABs é 100% Git. Sem dominar commit/branch/merge, você trava o fluxo de produção. Git também é a base do seu portfólio: entrevistadores pedem para ver seu repositório.

# %% [markdown]
# ## 📖 Teoria — Conceitos fundamentais
#
# **Repositório** = pasta versionada. **Commit** = snapshot do código com mensagem. **Branch** = linha de trabalho independente (ex.: `feature/x`, `workspace`). **Merge** = integrar branches. **Pull Request (PR)** = proposta de merge com revisão antes de integrar.
#
# **Fluxo Git simples e profissional**:
# ```
# main ──●───●───●───●
#            \         /
# feature ────●───●───
# ```
#
# **Regra de ouro**: commits pequenos, mensagens descritivas, e nunca trabalhar diretamente na `workspace` em equipes (sempre branch + PR).

# %% [markdown]
# ### 💻 Na prática — Configurando
#
# Rode no seu computador (não no notebook). Se não tiver Git instalado: https://git-scm.com/downloads.

# %%
# COMANDOS PARA O SEU TERMINAL LOCAL (não no Databricks)
# 1. Configurar identidade
# !git config --global user.name "Seu Nome"        # ajuste para seu nome
# !git config --global user.email "seu@email.com"  # ajuste para seu email
print("Configure sua identidade no terminal local!")

# %% [markdown]
# ### 💻 Na prática — Criando o repositório
#
# 1. Crie um repo **vazio** no GitHub (sem README).
# 2. No terminal:
# ```
# git clone https://github.com/SEU_USUARIO/databricks-course.git
# cd databricks-course
# ```
# 3. Adicione os arquivos e o primeiro commit.

# %%
# Fluxo básico (terminal local)
# !git add README.md
# !git commit -m "docs: README inicial do curso"
# !git push origin main
print("Fluxo: git add -> git commit -> git push")

# %% [markdown]
# ### 💻 Na prática — Branches e merge
#
# Trabalhe em uma branch e integre com PR — o fluxo que as empresas usam.

# %%
# Terminal local
# !git checkout -b feature/primeiro-notebook
# !git add .
# !git commit -m "feat: primeiro notebook da Semana 1"
# !git push origin feature/primeiro-notebook
print("Abra o GitHub e crie um Pull Request da branch para main.")

# %% [markdown]
# ## 📖 Teoria — Bons padrões de commit (conventional commits)
#
# Formato `tipo(escopo): descrição`:
# - `feat:` nova funcionalidade
# - `fix:` correção
# - `docs:` documentação
# - `refactor:` reorganização sem mudar comportamento
# - `test:` testes
#
# Ex.: `feat: cria pipeline de vendas Bronze` · `docs: adiciona diagrama Medallion`
#
# > 🎯 **Dica de prova (DEP)**: a prova cobra o fluxo de trabalho com Git em Databricks Repos (branch, PR, integração com CI). Saber `git add/commit/push` e branches é o mínimo.

# %% [markdown]
# > 🎯 **Dica de prova**: Databricks Repos integra seu repositório Git ao workspace: você edita notebooks direto no branch e faz merge via PR. Sem Git, não há Repos.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** O que faz cada comando: add, commit, push, pull, merge?
#
# **2.** Crie uma branch, altere um arquivo, faça commit e abra um PR no GitHub.
#
# **3.** Qual a diferença entre merge e pull request?
#
# **4.** Escreva 3 mensagens de commit seguindo conventional commits.
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** Comandos
#
# add = marca mudanças para o próximo commit; commit = snapshot com mensagem; push = envia commits locais ao remoto; pull = traz commits do remoto; merge = integra uma branch em outra.
#
# **2.** Exercício prático
#
# `git checkout -b nova-branch` → edite → `git add .` → `git commit -m` → `git push origin nova-branch` → GitHub: New Pull Request → merge.
#
# **3.** Merge vs PR
#
# Merge é a operação técnica de integrar; PR é o processo de propor/revisar a integração (code review, testes antes de aceitar).
#
# **4.** Conventional commits
#
# Ex.: `feat: adiciona constraint de qualidade`, `fix: corrige timezone da data`, `docs: atualiza README do projeto`.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
