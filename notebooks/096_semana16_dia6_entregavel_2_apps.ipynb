# %% [markdown]
# # 📓 Semana 16 · Dia 6 — Entregável: 2 apps publicados e monitorados
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | Portfólio |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | 2 apps no ar + README |
#
# ---

# %% [markdown]
# ## 📖 Teoria — O que a Semana 16 entregou
#
# - Arquitetura de Apps (app.yaml, auth, scale)
# - App de BI (Streamlit + Ouro)
# - App de chat RAG (citações + feedback)
# - Backend FastAPI
# - CI/CD via DABs + observabilidade

# %% [markdown]
# ### 💻 Na prática — Entregável final
#
# 1. Publique o app de BI.
# 2. Publique o app de chat RAG.
# 3. Adicione ambos ao bundle.
# 4. Documente no README (links, arquitetura).

# %%
# Checklist dos apps
print("""
- [x] App BI publicado (KPIs + gráficos)
- [x] App RAG publicado (chat + fontes + feedback)
- [x] API FastAPI funcional
- [x] Apps no DABs (dev/prod)
- [x] Logs e métricas conferidos
- [x] Links no README
""")
print("Na Free: 3 apps no máximo — planeje os próximos (Semanas 17-18).")

# %% [markdown]
# > 🎯 **Dica de prova**: Portfólio: ter 2 apps no ar (BI + RAG) com README e arquitetura documentada é prova concreta de habilidade — vale mais que certificado sozinho.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Compartilhe os links dos apps com alguém e peça feedback.
#
# **2.** Qual app você melhoraria com base no feedback?
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** Feedback
#
# Use os 👍/👎 e os comentários para priorizar a próxima versão.
#
# **2.** Melhoria
#
# Ex.: adicionar filtro por país no RAG, mais KPIs no BI, ou streaming de resposta.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Publiquei 2 apps (BI + RAG).
# - [ ] Entendo app.yaml e o fluxo de deploy.
# - [ ] Configurei CI/CD via DABs.
# - [ ] Monitorei logs e métricas.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
