# %% [markdown]
# # 📓 Semana 9 · Dia 3 — Serverless compute e Lakeflow Connect
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition (conceito) + 🔑 Lakeflow Connect (trial) |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | DEP (2026) |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | Matriz de decisão de compute documentada |
#
# ---

# %% [markdown]
# ## 📖 Teoria — Serverless compute (DEP 2026)
#
# O **serverless** elimina a gestão de clusters: o Databricks provisiona e escala o compute sob demanda (notebooks, jobs, SQL).
#
# Vantagens: zero configuração, scale-to-zero (paga só quando roda), manutenção automática. Trade-off: menos controle fino (pool, políticas) e preço por DBU diferente.
#
# **Quando usar**: ad hoc, workloads variáveis, times sem infra dedicada.
# **Quando usar clássico (pago)**: workload estável e previsível, necessidade de init scripts/policies, GPU dedicada.

# %% [markdown]
# ## 📖 Teoria — Lakeflow Connect (DEP 2026)
#
# O **Lakeflow Connect** é a ingestão **gerenciada e sem código** de fontes externas (SaaS como Salesforce, Workday, ServiceNow, bancos de dados) direto para o Lakehouse, com incrementais e schema automáticos.
#
# > ⚠️ Lakeflow Connect é recurso de conta paga — na Free estude o conceito e valide no trial.

# %% [markdown]
# ### 💻 Na prática — Matriz de decisão de compute
#
# Complete a tabela de decisão do seu projeto.

# %%
# Matriz de decisão (complete com seus casos)
matriz = """
| Caso | Compute ideal | Por quê |
|---|---|---|
| Consulta ad hoc de BI | SQL Warehouse serverless | escala + auto-stop |
| Job diário estável | Job cluster / serverless jobs | paga só na execução |
| Streaming contínuo | Continuous (pago) | latência |
| Notebook exploratório | Notebook serverless | sem config |
| Fine-tune GPU | GPU cluster (pago) | GPU dedicada |
"""
print(matriz)

# %%
# Lakeflow Connect — fluxo (trial)
print("""
1. Catalog > Add > Source (Lakeflow Connect)
2. Escolha a fonte (Salesforce, Workday, Postgres...)
3. Credenciais + tabelas/objetos
4. Defina frequência (incremental automático)
5. Pronto: tabelas bronze atualizadas sem código
""")
print("Ingestão gerenciada — padrão para integrar SaaS sem engenharia manual.")

# %% [markdown]
# > 🎯 **Dica de prova**: DEP 2026 adicionou **Serverless Compute** e **Lakeflow Connect** ao escopo. Memorize: serverless = sem cluster próprio; Connect = ingestão SaaS sem código.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Diferencie serverless de cluster clássico em 2 frases.
#
# **2.** Qual recurso ingere Salesforce sem código?
#
# **3.** Quando você escolheria cluster clássico em vez de serverless?
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** Serverless
#
# Serverless: plataforma gerencia tudo, escala sob demanda, paga por uso. Clássico: você controla máquinas, init scripts e políticas.
#
# **2.** Lakeflow Connect
#
# Lakeflow Connect — ingestão gerenciada de SaaS/bancos direto para o Lakehouse.
#
# **3.** Clássico
#
# Quando precisa de init scripts, cluster policies, GPU estável ou workloads previsíveis que justificam cluster dedicado.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
