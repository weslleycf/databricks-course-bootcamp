# %% [markdown]
# # 📓 Semana 9 · Dia 4 — Genie (AI/BI): análise em linguagem natural
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | DAA (Genie 2026), GenAI |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | Genie space respondendo perguntas do projeto |
#
# ---

# %% [markdown]
# ## 📖 Teoria — O que é o Genie
#
# O **Genie** é o assistente conversacional de BI do Databricks: você pergunta em linguagem natural ('qual o país com mais receita em novembro?') e ele gera/executa SQL sobre as tabelas que você autorizou.
#
# - **Genie spaces**: coleções de tabelas + instruções para o assistente
# - **Genie Code**: modo que mostra o SQL gerado (transparência e correção)
# - **Ontologia** (DAIS 2026, 🔑): define métricas e cálculos padrão — o Genie não erra conta porque conhece a definição oficial

# %% [markdown]
# ### 💻 Na prática — Criando um Genie space
#
# 1. **AI/BI → Genie → New space**.
# 2. Adicione as tabelas: `workspace.ouro.vendas_por_dia`, `workspace.ouro.receita_por_pais`, `workspace.ouro.top_produtos`.
# 3. Escreva instruções (prompt do space): 'Sempre use receita como Quantity*UnitPrice; responda em português'.
# 4. Pergunte: 'Qual o top 5 de países por receita?'

# %% [markdown]
# ### 💻 Na prática — Genie Code
#
# No Genie, ative o **Code mode** para ver o SQL gerado — aprenda com ele e valide a resposta.

# %%
# O que o Genie gera (exemplo do SQL por trás da resposta)
sql_exemplo = """
SELECT Country, SUM(Quantity * UnitPrice) AS receita
FROM workspace.bronze.vendas_bronze
GROUP BY Country
ORDER BY receita DESC
LIMIT 5
"""
print(sql_exemplo)
print("Valide: rode este SQL você mesmo e compare com a resposta do Genie.")

# %% [markdown]
# ### 💻 Na prática — Perguntas de negócio
#
# Teste o Genie com perguntas cada vez mais complexas.

# %%
# Perguntas para testar no Genie
perguntas = """
1. Qual o ticket médio por país?
2. Compare a receita de novembro vs outubro.
3. Quais os 3 produtos mais vendidos no Reino Unido?
4. Qual a receita acumulada por mês em 2024?
5. (Ontologia, 🔑) Qual o ARPU por cliente?
"""
print(perguntas)

# %% [markdown]
# > 🎯 **Dica de prova**: DAA 2026 inclui **Genie**. Pergunta típica: 'qual ferramenta responde perguntas em linguagem natural sobre dados?' → Genie; 'como garantir que a métrica está correta?' → Genie Ontology (definição canônica).

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Crie um Genie space com 3 tabelas e faça 5 perguntas.
#
# **2.** Qual a vantagem do Genie Code mode?
#
# **3.** O que a Ontologia resolve?
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** Space
#
# AI/BI → Genie → New space → tabelas → instruções → perguntar.
#
# **2.** Code mode
#
# Mostra o SQL gerado: transparência, aprendizado e correção manual quando a resposta não fizer sentido.
#
# **3.** Ontologia
#
# Define métricas e cálculos oficiais — o Genie usa a definição canônica e para de 'inventar' fórmulas (a causa nº 1 de erro em BI conversacional).

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
