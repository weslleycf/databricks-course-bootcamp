# %% [markdown]
# # 📓 Semana 11 · Dia 1 — LLMs: tokens, contexto e Foundation Model APIs
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition (FMA com quota) |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | GenAI Engineer Associate |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | Primeira chamada a um LLM via FMA |
#
# ---

# %% [markdown]
# ## 📖 Teoria — O que é um LLM
#
# Um **LLM (Large Language Model)** prevê o próximo token de uma sequência. Conceitos-base:
#
# - **Token**: unidade de texto (palavra/pedaço). 1 token ≈ 0,75 palavra em inglês.
# - **Janela de contexto**: nº máximo de tokens que o modelo 'enxerga' por chamada (ex.: 8k, 128k). Passou disso = truncamento.
# - **Temperature**: aleatoriedade da saída (0 = determinístico; 1 = criativo).
# - **System prompt**: instruções permanentes; **user prompt**: pedido da vez.
#
# > 🎯 **Dica de prova (GenAI Assoc)**: 'o que é a janela de contexto?' → limite de tokens de entrada+saída por chamada. Custo ≈ tokens processados.

# %% [markdown]
# ## 📖 Teoria — Foundation Model APIs (FMA)
#
# As **Foundation Model APIs** do Databricks dão acesso a modelos (Llama, Mistral, GPT via gateway) com **um endpoint único** e **Unity Catalog governance**: `serving_endpoint` apontando para `databricks-llama-3-1-70b`, por exemplo.
#
# Na Free Edition, as FMAs existem **com quota de uso** (limite diário) — suficiente para o curso.

# %% [markdown]
# ### 💻 Na prática — Primeira chamada via FMA
#
# Use o MLflow Deployments para chamar um endpoint de FMA.

# %%
# Listar endpoints de FMA disponíveis
from mlflow.deployments import get_deploy_client
client = get_deploy_client("databricks")
endpoints = client.list_endpoints()
print([e.name for e in endpoints])

# %%
# Chamada a um LLM via FMA (ajuste o nome ao endpoint disponível)
endpoint = "databricks-llama-3-1-70b"
resp = client.predict(
    endpoint=endpoint,
    inputs={"messages": [
        {"role": "system", "content": "Você é um assistente de dados."},
        {"role": "user", "content": "Explique em 1 frase o que é o Lakehouse."}
    ], "temperature": 0.2})
print(resp["choices"][0]["message"]["content"])

# %%
# Playground (exploratório)
print("""
1. AI > Playground
2. Escolha o modelo (ex.: Llama 3.1 70B)
3. Teste: temperature 0 vs 1, system prompts diferentes
4. Veja a contagem de tokens
""")
print("O Playground é o melhor laboratório para entender temperature.")

# %% [markdown]
# > 🎯 **Dica de prova**: GenAI Assoc: FMA = Foundation Model APIs, acessadas via MLflow Deployments com governance do UC. Pergunta: 'como chamar um modelo hospedado no Databricks?' → FMA/serving endpoint.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** O que acontece se o prompt passar da janela de contexto?
#
# **2.** Teste a MESMA pergunta com temperature 0 e 1 — o que muda?
#
# **3.** Quantos tokens tem aproximadamente a frase 'Databricks é uma plataforma de dados'?
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** Janela excedida
#
# O conteúdo é truncado (entrada cortada) ou a chamada falha — por isso RAG envia só trechos relevantes, não o documento inteiro.
#
# **2.** Temperature
#
# 0 → respostas quase idênticas e determinísticas; 1 → variadas e criativas. Para SQL/JSON, use ~0.
#
# **3.** Tokens
#
# ~5–8 tokens (português usa ~1,3–1,8 token/palavra).

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
