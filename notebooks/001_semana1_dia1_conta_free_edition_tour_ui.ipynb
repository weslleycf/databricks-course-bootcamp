# %% [markdown]
# # 📓 Semana 1 · Dia 1 — Conta Free Edition, Tour da Interface e Primeiro Notebook
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | DEA (fundações da plataforma) |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | Conta criada + notebook `00_bem_vindo` rodando |
#
# > 🎯 **DAIS 2026**: AI Assistant integrado na UI para escrever e corrigir código.
#
# ---

# %% [markdown]
# ## 📖 Teoria — A nova Databricks Free Edition
#
# Até meados de 2025, a Databricks oferecia a *Community Edition* para quem queria estudar sem pagar. Ela foi aposentada em junho de 2025 e substituída pela **Free Edition**: um workspace real na nuvem, com **compute serverless** (você não configura máquinas — a plataforma provisiona e escala sozinha) e acesso à maioria dos produtos: Unity Catalog, Delta Lake, SQL, Lakeflow, Apps e Mosaic AI.
#
# **Limitações importantes da Free Edition** (que vamos respeitar o curso todo):
# - Uso **não comercial**, sem SLA e sem suporte dedicado.
# - 1 SQL Warehouse (tamanho 2X-Small).
# - Máx. 5 jobs/tarefas concorrentes e **1 pipeline Lakeflow ativo por tipo**.
# - Até 3 Databricks Apps (com auto-stop após 24h) e **1 projeto Lakebase**.
# - Model Serving limitado: sem GPU, sem throughput provisionado, alguns modelos indisponíveis.
# - Internet de saída restrita a domínios confiáveis (verificação via LinkedIn libera GPU limitada e acesso a mais domínios).
# - Sem R/Scala, sem external locations, sem account console, sem SSO/SCIM.
# - Contas inativas por muito tempo podem ser excluídas — **use o workspace toda semana**.
#
# > 💡 **Analogia**: a Free Edition é como um carro de luxo de demonstração: você dirige tudo de verdade, mas com um tanque pequeno e sem sair do estacionamento do concessionário. Para o estudo é perfeita — e 85% do que um especialista faz cabe nela.

# %% [markdown]
# ### 💻 Na prática — Criando a conta
#
# 1. Acesse https://www.databricks.com/try-databricks e clique em **Get Started** com **Free Edition**.
# 2. Cadastre-se com e-mail (OTP), Google ou Microsoft (não há SSO/SCIM na Free).
# 3. Confirme o e-mail. O workspace é criado em poucos minutos.
# 4. **Anote o URL do workspace** (formato `dbc-xxxx.cloud.databricks.com`) e a senha.
#
# > ⚠️ A Free Edition pode pedir verificação de identidade via **LinkedIn** para liberar limites extras (GPU, internet). É opcional, mas recomendado.

# %% [markdown]
# ## 📖 Teoria — O tour da interface
#
# **Sidebar esquerda** (navegação principal):
# - **Home**: atalhos para notebooks, queries e dashboards recentes.
# - **Workspace**: onde ficam notebooks e pastas (equivalentes a arquivos).
# - **Data**: Unity Catalog — catálogos, schemas, tabelas, volumes, funções e modelos.
# - **Compute**: SQL Warehouses e computação (na Free, serverless).
# - **Jobs**: orquestração de pipelines (Lakeflow Jobs).
# - **Experiments / Models**: MLflow.
# - **Apps / Lakebase**: publicar aplicações e criar projetos transacionais.
# - **AI**: Playground, Mosaic AI, Vector Search, agentes.
# - **Search**: busca global (Ctrl+K).

# %% [markdown]
# ## 📖 Teoria — Notebooks e comandos mágicos
#
# O notebook é dividido em **células**. Cada célula roda em uma linguagem definida por um **comando mágico** no topo da célula:
#
# | Comando | Linguagem / efeito |
# |---|---|
# | `%python` | Python (padrão) |
# | `%sql` | Spark SQL |
# | `%md` | Markdown (documentação) |
# | `%sh` | Shell no nó do driver |
# | `%fs` | Comandos de arquivos (ex.: `%fs ls`) |
# | `%scala` / `%r` | Scala / R (⚠️ não disponíveis na Free Edition) |
#
# > 🎯 **Dica de prova (DEA)**: a prova cobra a diferença entre `%sql`, `%python` e `%md`, e o fato de que células SQL compartilham o mesmo catálogo do notebook. O comando `%fs` acessa o sistema de arquivos, não o catálogo.

# %% [markdown]
# ### 💻 Na prática — Primeiro código
#
# Rode a célula abaixo com **Shift+Enter**. Em notebooks Databricks, `spark` já existe como uma variável global — você não precisa criá-la.

# %%
# Célula Python — primeiro contato com o ambiente
print("Bem-vindo(a) ao curso Especialista Databricks!")
print("Versão do Spark:", spark.version)
print("Versão do Databricks Runtime:", spark.conf.get("spark.databricks.clusterUsageTags.sparkVersion"))

# %% [markdown]
# ### 💻 Na prática — SQL no notebook
#
# Células SQL rodam no mesmo catálogo do notebook. Experimente:

# %%
# %sql
SELECT 1 + 1 AS soma, current_date() AS hoje

# %% [markdown]
# ### 💻 Na prática — Markdown e documentação
#
# Use `%md` para documentar — anotações, diagramas ASCII, checklists. Um notebook bem documentado vale ouro em equipes (e em entrevistas, mostrando comunicação).

# %% [markdown]
# %md
# ### 📝 Anotações do Dia 1
#
# - [x] Conta Free Edition criada
# - [x] Tour pela interface concluído
# - [ ] Primeiro notebook rodando (falta validar)

# %% [markdown]
# > 🎯 **Dica de prova**: Na Free Edition, notebooks rodam em **compute serverless** — você não cria clusters como na versão clássica. A prova DEA 2026 cobra serverless como conceito e as diferenças para clusters clássicos.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Qual a diferença entre a antiga Community Edition e a nova Free Edition?
#
# **2.** Quais são 3 limitações da Free Edition que afetam o plano de estudo?
#
# **3.** Cite 3 comandos mágicos e o que cada um faz.
#
# **4.** O que a verificação via LinkedIn libera na Free Edition?
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** Community Edition x Free Edition
#
# A CE foi aposentada em junho/2025. A FE é serverless-only, com quotas (1 SQL warehouse 2X-Small, 5 jobs concorrentes, 1 pipeline Lakeflow ativo por tipo, 3 Apps, 1 Lakebase, model serving sem GPU) e sem R/Scala, sem external locations, sem account console e sem SSO/SCIM.
#
# **2.** 3 limitações
#
# Ex.: 1 pipeline Lakeflow ativo por tipo; máx. 5 jobs concorrentes; model serving sem GPU/provisioned throughput; até 3 Apps com auto-stop 24h; internet de saída restrita.
#
# **3.** Comandos mágicos
#
# `%sql` roda Spark SQL; `%python` roda Python; `%md` insere Markdown; `%fs` acessa o sistema de arquivos; `%sh` roda shell. `%scala`/`%r` não existem na Free Edition.
#
# **4.** LinkedIn verification
#
# Libera acesso a GPU serverless limitada e internet de saída mais ampla — útil nas semanas de fine-tuning e integrações.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
