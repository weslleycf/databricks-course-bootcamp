# %% [markdown]
# # 📓 Semana 6 · Dia 2 — DABs: Databricks Asset Bundles (IaC)
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition (validate/plan local) | 🔑 Versão paga (deploy) |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | DEP (IaC) |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | Bundle validado localmente |
#
# ---

# %% [markdown]
# ## 📖 Teoria — O que são DABs
#
# **Databricks Asset Bundles (DABs)** é o formato de **Infraestrutura como Código** (IaC) do Databricks: você define jobs, pipelines, notebooks e apps em YAML, e o Databricks **implantar** tudo com `bundle deploy`.
#
# Vantagens: versionado no Git, replicável em N ambientes, revisável em PR, e padrão oficial de produção (DEP).

# %% [markdown]
# ## 📖 Teoria — Estrutura de um bundle
#
# ```
# meu_bundle/
#  ├── databricks.yml        # definição principal (recursos, targets)
#  ├── resources/
#  │   ├── jobs/             # jobs do bundle
#  │   └── pipelines/        # pipelines DLT
#  └── src/                  # código-fonte (notebooks, .py)
# ```
#
# `databricks.yml` tem 3 blocos-chave: `bundle` (nome), `resources` (o que implantar), `targets` (ambientes dev/staging/prod com variáveis).

# %% [markdown]
# ### 💻 Na prática — Criando o bundle
#
# Com o **Databricks CLI** instalado (`brew install databricks` / `pip install databricks-cli` — use o novo `databricks` CLI):

# %%
# Terminal local — iniciar bundle
# !mkdir -p ~/bundle_vendas && cd ~/bundle_vendas
# !databricks bundle init default-python
print("Bundle criado: databricks.yml + src/ + resources/")

# %%
# databricks.yml mínimo (referência — crie/edit no seu projeto)
yaml = """
bundle:
  name: vendas_bundle
resources:
  jobs:
    job_ingestao:
      name: job_ingestao
      tasks:
        - task_key: t1
          notebook_task:
            notebook_path: ./src/ingestao.ipynb
targets:
  dev:
    mode: development
  prod:
    mode: production
"""
print(yaml)

# %% [markdown]
# ### 💻 Na prática — Validate e plan
#
# Valide o bundle localmente (sem deploy) — isso roda na Free Edition.

# %%
# Terminal local
# !databricks bundle validate -t dev
# !databricks bundle plan -t dev
print("Validate/plan checam sintaxe, recursos e variáveis sem deploy.")

# %% [markdown]
# > 🎯 **Dica de prova**: DABs é tema central da DEP 2026: estrutura (databricks.yml, resources, targets), comandos (validate, plan, deploy, run) e o papel no CI/CD. Decore os 4 comandos.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Descreva a estrutura mínima de um bundle.
#
# **2.** Qual a diferença entre validate e plan? E deploy?
#
# **3.** O que `targets` define?
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** Estrutura
#
# databricks.yml + resources/ (jobs, pipelines) + src/ (código).
#
# **2.** Comandos
#
# validate = checa sintaxe/config local; plan = mostra o que seria implantado; deploy = aplica no workspace; run = executa o recurso.
#
# **3.** targets
#
# Ambientes (dev/staging/prod) com modos, variáveis e configurações específicas de cada um.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
