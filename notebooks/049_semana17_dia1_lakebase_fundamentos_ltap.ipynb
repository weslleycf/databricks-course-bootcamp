# %% [markdown]
# # 📓 Semana 17 · Dia 1 — Lakebase: arquitetura LTAP e projetos
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition (1 projeto) |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | GenAI Assoc (retrieval avançado) |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | Projeto Lakebase criado |
#
# > 🎯 **DAIS 2026**: LTAP (Lakebase) e Delta UniForm 3.0 (DAIS 2026).
#
# ---

# %% [markdown]
# ## 📖 Teoria — O que é o Lakebase
#
# O **Lakebase** é o banco transacional nativo do Databricks (LTAP — Transactional Analytical Processing): ACID transacional (como Postgres) sobre o Delta Lake, com integração total ao Unity Catalog e ao resto do Lakehouse.
#
# Casos: app transacional (pedidos, configurações), estado de agentes, memória de conversa — sem sair da plataforma.
#
# Na Free Edition: **1 projeto Lakebase** com scale-to-zero.

# %% [markdown]
# ### 💻 Na prática — Criando o projeto
#
# Pela UI: **Lakebase → Create project**.

# %%
# Projeto Lakebase via API/CLI (visão geral)
print("""
1. Lakebase > Create project
2. Nome: lakebase_agente
3. Região (a mesma do workspace)
4. Criado com scale-to-zero (paga só quando usa)
""")
print("O projeto expõe uma connection (Postgres wire protocol) para apps.")

# %% [markdown]
# ## 📖 Teoria — Delta vs Lakebase
#
# | | Delta (analítico) | Lakebase (transacional) |
# |---|---|---|
# | Uso | OLAP (leitura pesada) | OLTP (escrita pontual) |
# | Latência | segundos | milissegundos |
# | API | Spark SQL | Postgres wire / API |
# | Consistência | ACID por transação | ACID transacional forte |
#
# Complementares: Lakebase para apps; Delta para análise.

# %% [markdown]
# > 🎯 **Dica de prova**: LTAP = transacional + analítico num só lugar. Pergunta: 'onde rodar o estado transacional de um app?' → Lakebase.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Diferença entre Delta e Lakebase em 2 frases.
#
# **2.** Quais dados do seu projeto fariam sentido no Lakebase?
#
# **3.** O que scale-to-zero significa para o custo do projeto?
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** Delta vs Lakebase
#
# Delta: analítico, leitura pesada, Spark. Lakebase: transacional, escrita pontual, latência baixa.
#
# **2.** Dados transacionais
#
# Estado de conversas, sessões, preferências de usuário, pedidos — dados que mudam com frequência.
#
# **3.** Scale-to-zero
#
# Sem uso, o projeto desliga — custo zero quando ocioso.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
