# %% [markdown]
# # 📓 Semana 19 · Dia 6 — Checklist de 40 competências, repositório final e roadmap
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | Carreira |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | Checklist completo + repo final |
#
# ---

# %% [markdown]
# ## 📖 Teoria — As 40 competências do Especialista Databricks
#
# **Plataforma (1–5)**: workspace/notebooks · SQL warehouse · UC 3 níveis · Volumes · compute serverless
# **Engenharia (6–13)**: Spark SQL/DataFrame · Delta (ACID/time travel/merge) · Medallion · Auto Loader · Streaming · DLT · Jobs · DABs+CI/CD
# **Governança (14–20)**: RLS/masking · linhagem · system tables · Federation · Sharing · custos · CLI/API
# **Performance (21–23)**: Liquid Clustering · OPTIMIZE/VACUUM · tuning (AQE/broadcast/cache)
# **ML/MLOps (24–26)**: MLflow · Feature Engineering · Model Serving
# **GenAI (27–30)**: FMA+prompts · embeddings/chunking · Vector Search · avaliação/gateway
# **Agentes (31–34)**: ReAct/Reflexion/multi · tools UC · Text-to-SQL · MCP/Ontologia
# **Aplicações (35–38)**: Apps (Streamlit/Next.js) · Lakebase/pgvector · segurança · observabilidade
# **Carreira (39–40)**: entrevista EN · portfólio

# %% [markdown]
# ### 💻 Na prática — Checklist interativo
#
# Marque as competências que você domina.

# %%
# Checklist (rode e marque 1 para dominadas)
competencias = {
    "Delta Time Travel": 1, "DLT expectations": 1, "SCD2": 1,
    "DABs + CI/CD": 1, "RLS/masking": 1, "Liquid Clustering": 1,
    "MLflow evaluate": 1, "RAG (4 métricas)": 1, "Agente ReAct": 1,
    "Apps full-stack": 1, "Lakebase": 1, "MCP": 1,
}
dominadas = sum(competencias.values())
print(f"{dominadas}/{len(competencias)} competências-chave dominadas")
print("Objetivo: 12/12 — se faltar, revise a semana correspondente.")

# %% [markdown]
# ### 💻 Na prática — Repositório final
#
# Estrutura profissional do GitHub:

# %%
# Estrutura do repo final
print("""
databricks-course/
 ├── README.md          # arquitetura + links + métricas
 ├── notebooks/         # 114 notebooks do curso
 ├── apps/              # dashboard + chat RAG + full-stack
 ├── bundles/           # DABs (jobs, pipelines, apps)
 ├── .github/           # CI/CD
 └── docs/              # ADRs, diagramas, glossário EN
""")
print("Estruture o repo e faça o commit final.")

# %% [markdown]
# ### 💻 Na prática — Roadmap pós-curso
#
# 1. Agende as provas (DEA → GenAI → DEP → MLP opcional).
# 2. Recertificação a cada 2 anos.
# 3. Evolua: contribua a open source, blog sobre o projeto.
# 4. Aplique para vagas (DE sênior / GenAI Engineer).

# %% [markdown]
# > 🎯 **Dica de prova**: O curso te deu: plataforma completa + 3–4 certificações + portfólio real. O que falta é só agendar as provas e aplicar — o conhecimento está construído.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Finalize o README com diagrama, métricas e links.
#
# **2.** Crie a lista de 10 empresas-alvo (internacionais) e os requisitos de cada vaga.
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** README
#
# Deve conter: visão, arquitetura (mermaid), tabela de entregáveis por fase, métricas do modelo/RAG, links dos apps, certificações.
#
# **2.** Empresas
#
# Liste requisitos e compare com suas 40 competências — preencha as lacunas com os notebooks.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Validei as 40 competências.
# - [ ] Finalizei o repositório profissional.
# - [ ] Tenho plano de certificações e recertificação.
# - [ ] 🎉 Curso concluído — Especialista Databricks!
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
