# %% [markdown]
# # 📓 Semana 19 · Dia 1 — Arquitetura do Projeto Final Unificado
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | Todas (revisão) |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | Diagrama de arquitetura completo |
#
# ---

# %% [markdown]
# ## 📖 Teoria — O que o Projeto Final une
#
# Tudo o que você construiu:
#
# ```
# Landing --AutoLoader--> Bronze --DLT--> Prata --DLT--> Ouro
#    |                                                 |
#    | (quality/expectations)                    BI (dashboards + Genie)
#    |                                                 |
#    |                                          ML (MLflow + feature eng)
#    |                                                 |
#    |                                          RAG (Vector Search + FMA)
#    |                                                 |
#    |                                          Agente (tools UC + MCP)
#    |                                                 |
#    |                                          Apps (Next.js + FastAPI)
#    └── Tudo versionado (DABs + CI/CD) e governado (UC)
# ```

# %% [markdown]
# ### 💻 Na prática — Documentando as decisões
#
# Escreva o documento de arquitetura (ADRs) do projeto.

# %%
# Decisões de arquitetura (documente no README/ADR)
adrs = """
1. Medallion (Bronze/Prata/Ouro) - por que: reprocessamento e qualidade
2. DLT para pipelines - por que: declarativo + expectations
3. Star schema na Prata - por que: BI e ML reutilizam
4. RAG com Vector Search + híbrido - por que: custo/qualidade
5. Agente com UC functions - por que: governança
6. Lakebase para estado - por que: transacional
7. Apps (Next.js + FastAPI) - por que: produto
"""
print(adrs)

# %% [markdown]
# ### 💻 Na prática — Diagrama final
#
# Desenhe o diagrama (mermaid/ASCII) no README — será a primeira imagem que entrevistadores veem.

# %% [markdown]
# > 🎯 **Dica de prova**: Entrevista: 'descreva sua arquitetura' → comece pelo diagrama, explique cada camada em 1 frase e justifique 2 decisões (por que DLT? por que RAG?).

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Desenhe o diagrama completo no README (mermaid).
#
# **2.** Liste 3 decisões que você mudaria em produção (e por quê).
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** Mermaid
#
# Use blocos: ingestão → bronze → prata → ouro → consumo (BI/ML/RAG/agente/app).
#
# **2.** Mudanças
#
# Ex.: DLT contínuo em vez de triggered; Lakebase para mais tabelas; multi-agente em produção.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
