# %% [markdown]
# # 📓 Semana 9 · Dia 2 — Gestão de custos: as 10 regras que economizam até 80%
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition (conceito) + 🔑 billing real (trial) |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | DEP (custos) |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | Política de custos documentada |
#
# ---

# %% [markdown]
# ## 📖 Teoria — Como o Databricks cobra
#
# A cobrança é por **DBU (Databricks Unit)**: uma unidade de processamento conforme o tipo de workload. Fatores da fatura:
# - Tipo de compute (serverless, SQL warehouse, jobs)
# - Tempo de execução × tamanho do cluster
# - Model serving / FMA (tokens)
#
# **Tags** marcam recursos por projeto/time/custo. **Budget alerts** avisam quando o gasto passa do limite.

# %% [markdown]
# ## 📖 Teoria — As 10 regras de economia
#
# 1. **Pare o que não usa** — auto-stop de warehouses/clusters (maior economia)
# 2. **Escolha o compute certo** — serverless para ad hoc; jobs para carga
# 3. **Reduza o shuffle** — broadcast join, chaves boas
# 4. **Use Delta/Liquid Clustering** — menos leitura, menos DBU
# 5. **Filtre cedo** — não leia colunas/linhas que não precisa
# 6. **Modo triggered** em vez de continuous quando possível
# 7. **Cache e result caching** para dashboards
# 8. **Evite UDFs** — expressões nativas
# 9. **Frequência certa de jobs** — diário em vez de horário
# 10. **Monitore** — system tables de billing, budget alerts

# %% [markdown]
# ### 💻 Na prática — Tags e budget (trial)
#
# Na conta paga: Compute → SQL Warehouse → Tags; e Billing → Budget alerts.

# %%
# Tags nos recursos
tags = """
# Compute > SQL Warehouse > Tags
# cost_center=curso
# project=vendas
# owner=wesll
"""
print(tags)
print("Tags permitem faturamento por projeto — essencial em empresas.")

# %%
# Consultar billing (produção)
billing_sql = """
SELECT usage_metadata.ws_id, sku_name,
       SUM(usage_quantity) AS dbu
FROM system.billing.usage
GROUP BY 1, 2 ORDER BY dbu DESC
"""
print(billing_sql)

# %% [markdown]
# > 🎯 **Dica de prova**: Pergunta de entrevista garantida: 'como reduzir custo de pipeline?' — cite 3 das 10 regras com justificativa. Na prova DEP, a pergunta vira 'qual configuração reduz custo X?' → auto-stop, triggered, serverless.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Liste 5 das 10 regras com uma frase de impacto cada.
#
# **2.** O que são tags e para que servem?
#
# **3.** Simule: um warehouse 2X-Small rodando 24h vs auto-stop em 15 min — onde está a economia?
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** 5 regras
#
# Auto-stop, compute certo, menos shuffle, clustering, triggered — cada uma corta DBUs desperdiçados.
#
# **2.** Tags
#
# Metadados (projeto/time/dono) nos recursos — base para chargeback e identificação de gasto anômalo.
#
# **3.** Auto-stop
#
# O warehouse ligado 24h cobra DBU mesmo ocioso; auto-stop em 15 min zera o custo de inatividade — a economia nº 1.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
