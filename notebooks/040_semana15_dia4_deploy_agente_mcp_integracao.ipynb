# %% [markdown]
# # 📓 Semana 15 · Dia 4 — Deploy do agente: UI, API e MCP
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition (partes) + 🔑 (serving) |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | GenAI Engineer Associate |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | Agente servido via endpoint + MCP |
#
# ---

# %% [markdown]
# ## 📖 Teoria — Canais de entrega de agentes
#
# - **UI**: Streamlit/Databricks App (Semana 16) — chat amigável
# - **API**: Model Serving endpoint — integração com qualquer sistema
# - **Mensageria**: Slack/Teams
# - **MCP (Model Context Protocol)**: padrão aberto (Anthropic, 2024) para expor ferramentas/dados a qualquer LLM — o 'USB-C' dos agentes

# %% [markdown]
# ### 💻 Na prática — Servindo o agente via API
#
# O agente LangChain vira endpoint (🔑 trial) e é chamado via REST.

# %%
# Chamar agente servido via REST (padrão de produção)
print("""
POST /serving-endpoints/agente_vendas/invocations
{
  "messages": [{"role": "user", "content": "Qual a receita do UK?"}],
  "databricks_options": {"return_traces": true}
}
-> resposta + traces (para auditoria)
""")
print("Qualquer app chama o agente como API — sem acoplar ao notebook.")

# %% [markdown]
# ### 💻 Na prática — MCP
#
# Conecte o agente a ferramentas MCP (ex.: calendário, CRM) — o padrão 2026.

# %%
# MCP (conceito — servidor expõe ferramentas)
print("""
1. Um servidor MCP expõe ferramentas (JSON-RPC):
   - tools/list, tools/call
2. O agente Databricks adiciona o servidor MCP como fonte de tools
3. Ex.: MCP do CRM -> o agente consulta clientes reais
""")
print("MCP = ferramentas padronizadas, interoperáveis entre LLMs.")

# %% [markdown]
# ### 💻 Na prática — UI rápida (Streamlit)
#
# Faça um chat simples que chama o agente.

# %%
# Chat Streamlit (roda no Databricks Apps, Semana 16)
import streamlit as st
st.title("Agente de Vendas")
pergunta = st.chat_input("Pergunte sobre vendas...")
if pergunta:
    st.write(agente_final.invoke({"input": pergunta})["output"])
print("Código do app Streamlit pronto (publicar na Semana 16).")

# %% [markdown]
# > 🎯 **Dica de prova**: Agentes/MCP: MCP padroniza ferramentas entre LLMs (protocolo aberto). Pergunta: 'como integrar um agente a sistemas externos?' → MCP ou API do serving endpoint.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Liste 3 ferramentas MCP úteis para um agente de vendas.
#
# **2.** O que `return_traces` faz na chamada do agente?
#
# **3.** Qual a diferença entre servir via endpoint e rodar no notebook?
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** MCP tools
#
# CRM (clientes), calendário (eventos), pagamentos (transações) — integrações prontas via protocolo.
#
# **2.** return_traces
#
# Retorna os traces da chamada — auditoria e debug da resposta.
#
# **3.** Endpoint vs notebook
#
# Endpoint: REST, escala, governança, monitoramento; notebook: manual, sem escala, não é produção.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
