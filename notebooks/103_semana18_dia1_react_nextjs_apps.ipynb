# %% [markdown]
# # 📓 Semana 18 · Dia 1 — Frontend React/Next.js nos Databricks Apps
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition (até 3 apps) |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | Portfólio (full-stack) |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | App Next.js inicial publicado |
#
# ---

# %% [markdown]
# ## 📖 Teoria — Full-stack nos Apps
#
# Os Databricks Apps suportam **qualquer stack**: além de Streamlit, você pode rodar **Next.js/React** (frontend) + **FastAPI** (backend) — o padrão moderno de produto de dados.
#
# Estrutura:
# ```
# app/
#  ├── app.yaml          # comando: next start (ou uvicorn)
#  ├── frontend/         # Next.js (React)
#  ├── backend/          # FastAPI
#  └── requirements.txt / package.json
# ```

# %% [markdown]
# ### 💻 Na prática — App Next.js mínimo
#
# Estrutura de um app React que chama a API.

# %%
# frontend/app/page.tsx (conceito Next.js)
tsx = """
'use client';
import { useEffect, useState } from 'react';

export default function Home() {
  const [resposta, setResposta] = useState("");
  useEffect(() => {
    fetch("/api/health")
      .then(r => r.json())
      .then(d => setResposta(d.status));
  }, []);
  return <h1>App de Vendas — API: {resposta}</h1>;
}
"""
print(tsx)
print("Componente React que consulta o backend.")

# %%
# app.yaml (Next.js)
yaml = """
command:
  - next
  - start
  - -p
  - "8080"
"""
print(yaml)

# %% [markdown]
# ### 💻 Na prática — Publicando
#
# 1. Suba a pasta com package.json + app.yaml.
# 2. **Apps → Create App**.
# 3. O build (npm install + next build) roda na plataforma.

# %% [markdown]
# > 🎯 **Dica de prova**: Apps full-stack: o Databricks builda e roda Next.js/FastAPI — sem Docker/K8s. Pergunta: 'que stacks os Apps suportam?' → Python e Node.js (Streamlit, Flask, FastAPI, Next.js...).

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Por que usar Next.js em vez de Streamlit?
#
# **2.** O que o app.yaml muda para um app Node?
#
# **3.** Publique o app Next.js mínimo.
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** Next.js vs Streamlit
#
# Next.js: controle total de UI/UX, componentes, SEO; Streamlit: BI rápido sem frontend.
#
# **2.** app.yaml Node
#
# O comando vira `next start` (ou `npm run start`) com a porta 8080.
#
# **3.** Publicar
#
# Pasta + app.yaml + Create App → o build gerencia npm.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
