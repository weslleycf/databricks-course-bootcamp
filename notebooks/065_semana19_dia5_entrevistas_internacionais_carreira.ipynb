# %% [markdown]
# # 📓 Semana 19 · Dia 5 — Entrevistas internacionais, salários e estratégia de carreira
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | Carreira |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | Material de entrevista pronto |
#
# ---

# %% [markdown]
# ## 📖 Teoria — O mercado internacional Databricks (2026)
#
# - **EUA**: Senior DE $150–220k; GenAI Engineer $160–240k
# - **UK**: £75–130k; **UE (Alemanha/Holanda)**: €85–140k
# - **Remoto internacional**: comum para sênior (fuso e inglês)
# - Certificações pesam: DEA/DEP + GenAI = diferenciador imediato

# %% [markdown]
# ### 💻 Na prática — 30 perguntas de entrevista (amostra — respostas no gabarito)
#
# Pratique as 10 primeiras em voz alta, em inglês.

# %% [markdown]
# ### Perguntas técnicas (EN)
#
# 1. Explain the Medallion architecture and when you would use it.
# 2. What is the difference between a managed and an external table?
# 3. How does Delta Lake's Time Travel work?
# 4. When would you use Liquid Clustering vs partitioning?
# 5. What is a shuffle and why is it expensive?
# 6. How do DABs help with CI/CD?
# 7. What is RAG and when would you choose it over fine-tuning?
# 8. How do you evaluate a RAG system?
# 9. What is the ReAct loop?
# 10. How do you secure a Text-to-SQL agent?

# %% [markdown]
# ## 📖 Teoria — Como responder (método STAR-técnico)
#
# Para cada pergunta: **Conceito** (1 frase) → **Como funciona** (mecânica) → **Exemplo do seu projeto** → **Trade-off/decisão**. Ex.:
#
# "I use the Medallion architecture to separate raw, cleaned and aggregated data. In my retail project, Auto Loader ingests CSV into Bronze, DLT with expectations builds Silver, and Gold serves dashboards and ML. The trade-off is extra storage for reproducibility."

# %% [markdown]
# ### 💻 Na prática — Portfólio e presença
#
# 1. README do repo com diagrama + métricas + links dos apps.
# 2. LinkedIn: título com 'Databricks' + certificações.
# 3. GitHub: projeto_final.ipynb + apps + DABs.
# 4. Contribua ao databricks-industry-solutions (open source).

# %% [markdown]
# > 🎯 **Dica de prova**: Entrevista: menos decoreba, mais 'decisão + porquê'. Prepare 3 histórias (pipelines, GenAI, governança) com o método STAR.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Grave-se respondendo 5 perguntas em inglês.
#
# **2.** Escreva seu perfil LinkedIn (EN) destacando o projeto.
#
# **3.** Complete as 30 perguntas (10/dia) com o gabarito.
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** Respostas 1–10
#
# 1) Bronze/Prata/Ouro com reprocessamento e qualidade. 2) UC gerencia vs LOCATION externo; DROP apaga vs preserva. 3) _delta_log + versionAsOf/timestampAsOf. 4) Cardinalidade e filtros (cluster para alta cardinalidade). 5) Movimento de dados entre partições (rede+disco). 6) IaC: validate/plan/deploy + targets. 7) RAG injeta contexto; FT muda comportamento. 8) 4 métricas de ouro + golden set. 9) Raciocina→age→observa. 10) SELECT-only + validação + RLS + auditoria.
#
# **2.** Perfil LinkedIn
#
# Headline: 'Data & AI Engineer — Databricks (DEA/DEP/GenAI)'. Destaque o projeto com links.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
