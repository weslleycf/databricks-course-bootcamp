# %% [markdown]
# # 📓 Semana 18 · Dia 6 — Entregável: app full-stack com agente
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition (até 3 apps) |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | Portfólio |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | App full-stack publicado e monitorado |
#
# ---

# %% [markdown]
# ## 📖 Teoria — A arquitetura final da Semana 18
#
# ```
# Next.js (UI + streaming)
#    → FastAPI (backend + rate limit + validação)
#       → Agente (tools UC + MCP)
#       → Lakehouse (Ouro) / Lakebase (sessões)
# ```

# %% [markdown]
# ### 💻 Na prática — Entregável final
#
# 1. Rode o app full-stack (frontend + backend).
# 2. Teste: KPIs, chat com streaming, feedback.
# 3. Confira logs e métricas.
# 4. Documente a arquitetura no README.

# %%
# Checklist do app full-stack
print("""
- [x] Next.js publicado (UI + streaming)
- [x] FastAPI publicado (endpoints + rate limit)
- [x] Agente integrado (tools + MCP)
- [x] Sessões no Lakebase
- [x] RBAC do UC respeitado
- [x] Logs/métricas/alertas
""")
print("Fase de apps concluída — próximo: Projeto Final (Semana 19).")

# %% [markdown]
# > 🎯 **Dica de prova**: Portfólio: um app full-stack com agente + Lakebase + segurança documentada é o entregável mais forte do curso — mostre o diagrama na entrevista.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Escreva o README do app (arquitetura, decisões, links).
#
# **2.** Prepare um demo de 5 minutos do app para entrevista.
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** README
#
# Diagrama 3 camadas + decisões (por que Next.js, FastAPI, Lakebase) + limitações Free.
#
# **2.** Demo
#
# Pergunta de vendas → streaming → fonte/tool → feedback — o ciclo completo em 5 min.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Publiquei app full-stack com agente.
# - [ ] Streaming + estados + feedback implementados.
# - [ ] Conectei MCP.
# - [ ] Segurança e observabilidade completas.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
