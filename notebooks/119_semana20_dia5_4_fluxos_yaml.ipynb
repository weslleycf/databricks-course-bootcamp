# %% [markdown]
# # 📓 Semana 20 · Dia 5 — Criando os 4 fluxos YAML do projeto
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | ✅ Free Edition |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | Portfólio empresarial |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | 4 fluxos YAML funcionando |
#
# ---

# %% [markdown]
# ## 📖 Teoria — Os 4 fluxos do varejo
#
# | Fluxo | Campos | Regras |
# |---|---|---|
# | **Metas** | vendedor, meta, mês | meta ≥ 0, mês válido |
# | **Descontos** | produto, percentual, validade | 0–100%, data futura |
# | **Preços** | produto, preço_novo, vigência | preço > 0 |
# | **Clientes** | nome, email, cidade | email válido |

# %% [markdown]
# ### 💻 Na prática — Criando os fluxos
#
# Salve cada fluxo como YAML versionado.

# %%
# Fluxo: Metas
metas_yaml = """
fluxo: metas
nome: Metas de Vendas
campos:
  - nome: vendedor
    tipo: string
    obrigatorio: true
  - nome: meta
    tipo: numero
    min: 0
  - nome: mes
    tipo: mes
"""
salvar_versao("metas", metas_yaml, "admin")
print("Fluxo metas salvo.")

# %%
# Fluxo: Descontos
descontos_yaml = """
fluxo: descontos
nome: Descontos Promocionais
campos:
  - nome: produto
    tipo: string
    obrigatorio: true
  - nome: percentual
    tipo: numero
    min: 0
    max: 100
  - nome: validade
    tipo: data
"""
salvar_versao("descontos", descontos_yaml, "admin")
print("Fluxo descontos salvo.")

# %%
# Fluxos: Preços e Clientes
precos_yaml = """
fluxo: precos
nome: Atualização de Preços
campos:
  - nome: produto
    tipo: string
    obrigatorio: true
  - nome: preco_novo
    tipo: numero
    min: 0.01
"""
clientes_yaml = """
fluxo: clientes
nome: Cadastro de Clientes
campos:
  - nome: nome
    tipo: string
    obrigatorio: true
  - nome: email
    tipo: string
  - nome: cidade
    tipo: string
"""
salvar_versao("precos", precos_yaml, "admin")
salvar_versao("clientes", clientes_yaml, "admin")
print("4 fluxos salvos e versionados.")

# %% [markdown]
# ### 💻 Na prática — Validando todos
#
# Rode o JSON Schema em cada fluxo salvo.

# %%
# Validar os 4 fluxos
for fid in ["metas", "descontos", "precos", "clientes"]:
    y = spark.sql(f"SELECT yaml_def FROM workspace.app.fluxo_versoes WHERE fluxo_id='{fid}' ORDER BY versao DESC LIMIT 1").collect()[0][0]
    try:
        validate(instance=yaml.safe_load(y), schema=json_schema)
        print(f"{fid}: válido")
    except Exception as e:
        print(f"{fid}: INVÁLIDO -> {e.message}")

# %% [markdown]
# > 🎯 **Dica de prova**: Portfólio: 4 fluxos reais com regras variadas provam o motor — cada tipo de regra (min/max, enum, data) é um caso de teste.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Adicione regra de e-mail válido ao fluxo clientes (regex no motor).
#
# **2.** Crie um 5º fluxo (ex.: estoque).
#
# **3.** Documente os 4 fluxos no README.
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** Email
#
# Regra regex `^[\w.+-]+@[\w-]+\.[\w.]+$` no campo email — validação na camada de consistência.
#
# **2.** Estoque
#
# Campos: produto, quantidade (min 0), armazém.
#
# **3.** README
#
# Tabela dos fluxos com campos e regras — a documentação do produto.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
