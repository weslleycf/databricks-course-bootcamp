# %% [markdown]
# # 📓 Semana 13 · Dia 3 — Fine-tuning: quando vale (e quando NUNCA vale)
#
# **Curso**: Especialista Databricks — Engenharia de Dados → GenAI → Agentes
#
# | Campo | Valor |
# |---|---|
# | **Plano** | 🔑 Versão paga (GPU) — conceito na Free |
# | **Tempo estimado** | 2h |
# | **Certificação alvo** | GenAI Engineer Associate, MLP |
# | **Pré-requisitos** | SQL e Python básicos · notebooks anteriores do curso |
# | **Entregável do dia** | Regra de decisão + demo de fine-tune |
#
# ---

# %% [markdown]
# ## 📖 Teoria — A regra de decisão definitiva
#
# | Problema | Solução |
# |---|---|
# | Modelo não sabe SEUS dados | **RAG** (contexto) |
# | Modelo não segue formato/estilo/tom | **Fine-tuning** |
# | Perguntas repetitivas de domínio fechado | Fine-tuning (após RAG) |
# | Falta de dados/conhecimento novo | RAG primeiro, sempre |
#
# **Regra de ouro**: comece com RAG + prompts. Fine-tuning só quando o RAG já está bom e o problema é formato/comportamento. **Fine-tuning NUNCA substitui o acesso a dados dinâmicos.**

# %% [markdown]
# ## 📖 Teoria — LoRA e QLoRA
#
# **LoRA**: treina pequenas matrizes de adaptação (menos parâmetros, menos custo). **QLoRA**: quantiza o modelo base (4-bit) para caber em menos GPU. Ambos permitem fine-tuning de modelos grandes com GPU modesta.

# %% [markdown]
# ### 💻 Na prática — Preparando o dataset de treino
#
# Formato chat: mensagens com system/user/assistant.

# %%
# Dataset de fine-tuning (formato chat)
dados = [
    {"messages": [
        {"role": "system", "content": "Você responde sobre vendas."},
        {"role": "user", "content": "Qual a receita total?"},
        {"role": "assistant", "content": "A receita total é 9.7 milhões."}
    ]},
    {"messages": [
        {"role": "system", "content": "Você responde sobre vendas."},
        {"role": "user", "content": "Qual o top país?"},
        {"role": "assistant", "content": "O top país é United Kingdom."}
    ]}
]
print("Dataset no formato chat (messages) pronto.")

# %%
# Fluxo de fine-tuning no Databricks (🔑 trial/GPU)
print("""
1. AI > Fine-tuning > Create
2. Base: Llama 3.1 (via FMA)
3. Dataset: tabela Delta com coluna messages
4. Método: LoRA (recomendado) ou QLoRA
5. Rode (GPU dedicada, 🔑)
6. Resultado vira modelo servível via Model Serving
7. Avalie: mesmo golden set do RAG — compare antes/depois
""")
print("Na Free, o fine-tuning real exige trial pago ou verificação LinkedIn (GPU limitada).")

# %% [markdown]
# ### 💻 Na prática — Avaliando o fine-tune
#
# Nunca fine-tune sem avaliar: rode o mesmo golden set no modelo base vs fine-tunado.

# %%
# Avaliação comparativa (base vs fine-tuned)
print("""
1. Chame o endpoint do modelo base e do fine-tunado
2. Mesmas 20 perguntas do golden set
3. Compare com mlflow.evaluate (faithfulness, answer relevance)
4. Se não melhorou: não vale o custo — volte ao RAG/prompt
""")
print("Avaliação é o que decide: fine-tune só se os números melhorarem.")

# %% [markdown]
# > 🎯 **Dica de prova**: GenAI Assoc: 'quando usar RAG vs fine-tuning?' é pergunta garantida. Resposta-padrão: RAG para conhecimento/dados; fine-tuning para formato/estilo; comece com RAG.

# %% [markdown]
# ## 🎯 Exercícios de fixação
#
# **1.** Dê 2 exemplos em que fine-tuning é a escolha certa.
#
# **2.** Dê 2 exemplos em que fine-tuning NÃO resolve.
#
# **3.** Qual a vantagem do LoRA sobre fine-tune completo?
#
#
# > Tente resolver **antes** de olhar o gabarito no final do notebook.

# %% [markdown]
# ## 🗝️ Gabarito comentado
#
# **1.** Certo
#
# 1) modelo precisa responder sempre em formato JSON específico da empresa; 2) tom/estilo de marca. (Conhecimento de dados → RAG.)
#
# **2.** Não resolve
#
# 1) dados que mudam todo dia (preços); 2) conhecimento novo não visto no treino — RAG é a resposta.
#
# **3.** LoRA
#
# Treina fração dos parâmetros: custo/latência de treino muito menores e GPU modesta — com qualidade próxima do full fine-tune.

# %% [markdown]
# ## ✅ Checklist de fechamento
#
# - [ ] Rodei todas as células do notebook do início ao fim sem erros.
# - [ ] Consigo explicar os conceitos de hoje em 3 frases (sem olhar o material).
# - [ ] Fiz os exercícios e conferi o gabarito.
# - [ ] Anotei as dúvidas que preciso revisar.
#
# ---
# *Próximo passo: siga para o notebook seguinte do plano do curso.*
